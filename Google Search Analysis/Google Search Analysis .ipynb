# %%
pip install pytrends
# Out:
# Collecting pytrends
#   Downloading https://files.pythonhosted.org/packages/68/ba/7a24a3723c790000faf880505ff1cc46f4d29f46dd353037938a070c4d23/pytrends-4.9.2-py3-none-any.whl
# Requirement already satisfied: lxml in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (4.9.3)
# Requirement already satisfied: requests>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (2.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\lenovo\anaconda3\lib\site-packages (from pytrends) (1.3.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (1.24.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests>=2.0->pytrends) (2019.9.11)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2023.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.12.0)
# Installing collected packages: pytrends
# Successfully installed pytrends-4.9.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   49
# Singapore                  47
# India                      35
# Tunisia                    30
# Pakistan                   28
# Hong Kong                  27
# Sri Lanka                  27
# South Korea                24
# Nepal                      23

# %%
data.reset_index().plot(x="geoName", 
                        y="Machine Learning", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
trends.build_payload(kw_list=["Tesla"])
data = trends.interest_by_region()
data = data.sort_values(by="Tesla", ascending=False)
data = data.head(10)
print(data)
# Out:
#                Tesla
# geoName
# Norway           100
# Serbia            77
# Denmark           61
# Canada            60
# United States     53
# Switzerland       52
# Sweden            48
# Singapore         46
# Austria           43
# Hong Kong         41

# %%
data.reset_index().plot(x="geoName", 
                        y="Tesla", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Tesla'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Tesla'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Tesla', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %%
print(1)
# Out:
# 1

# %%
# !pip install pycaret
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/f5/4b/2002980b046ac396618dfc152d384b812a78182b776ca77fe0ae5f80deac/pycaret-3.0.4-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/d6/0f/96b7309212a926c1448366e9ce69b081ea79d63265bde33f11cc9cfc2c07/psutil-5.9.5.tar.gz
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Using cached https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/23/0a/af81042bed41042479dbc53bcf42fdd4e7670eb0b43202e0864be3ec9abc/xxhash-3.3.0-cp37-cp37m-win_amd64.whl
# ...

# %%
print(1)
# Out:
# 1

# %%
import pycaret
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-bc14816cda88> in <module>
# ----> 1 import pycaret
#
# ModuleNotFoundError: No module named 'pycaret'
